# %%
import pandas as pd
df = pd.read_csv('titanic.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Lname        156 non-null    object
#  4   Name         156 non-null    object
#  5   Sex          156 non-null    object
#  6   Age          126 non-null    float64
#  7   SibSp        156 non-null    int64
#  8   Parch        156 non-null    int64
#  9   Ticket       156 non-null    object
#  10  Fare         156 non-null    float64
#  11  Cabin        31 non-null     object
#  12  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 16.0+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
# Информация о пассажирах женского пола
df[df['Sex']=='female'].head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 8            9         1       3    Johnson
# 9           10         1       2     Nasser
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 8     Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0      2
# 9                  Mrs. Nicholas (Adele Achem)  female  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 8            347742  11.1333   NaN        S
# ...

# %%
# Информация о выживших пассажирах женского пола
df[(df['Sex']=='female') & (df['Survived']==1)].head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 8            9         1       3    Johnson
# 9           10         1       2     Nasser
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 8     Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0      2
# 9                  Mrs. Nicholas (Adele Achem)  female  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 8            347742  11.1333   NaN        S
# ...

# %%
# Информация о выживших несовершеннолетних пассажирах женского пола
df[(df['Sex']=='female') & (df['Survived']==1) & (df['Age']<18)].head()
# Out:
#     PassengerId  Survived  Pclass          Lname  \
# 9            10         1       2         Nasser
# 10           11         1       3      Sandstrom
# 22           23         1       3        McGowan
# 39           40         1       3  Nicola-Yarred
# 43           44         1       2        Laroche
#
#                                 Name     Sex   Age  SibSp  Parch  \
# 9        Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 10              Miss. Marguerite Rut  female   4.0      1      1
# 22                        Miss. Anna  female  15.0      0      0
# 39                      Miss. Jamila  female  14.0      1      0
# 43   Miss. Simonne Marie Anne Andree  female   3.0      1      2
#
#            Ticket     Fare Cabin Embarked
# 9          237736  30.0708   NaN        C
# 10        PP 9549  16.7000    G6        S
# 22         330923   8.0292   NaN        Q
# 39           2651  11.2417   NaN        C
# 43  SC/Paris 2123  41.5792   NaN        C

# %%
# Информация о пассажирах мужского пола
df[df['Sex']=='male'].head()
# Out:
#    PassengerId  Survived  Pclass     Lname                    Name   Sex  \
# 0            1         0       3    Braund         Mr. Owen Harris  male
# 4            5         0       3     Allen       Mr. William Henry  male
# 5            6         0       3     Moran               Mr. James  male
# 6            7         0       1  McCarthy           Mr. Timothy J  male
# 7            8         0       3   Palsson   Master. Gosta Leonard  male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  22.0      1      0  A/5 21171   7.2500   NaN        S
# 4  35.0      0      0     373450   8.0500   NaN        S
# 5   NaN      0      0     330877   8.4583   NaN        Q
# 6  54.0      0      0      17463  51.8625   E46        S
# 7   2.0      3      1     349909  21.0750   NaN        S

# %%
# Информация о выживших пассажирах мужского пола
df[(df['Sex']=='male') & (df['Survived']==1)].head()
# Out:
#     PassengerId  Survived  Pclass     Lname                   Name   Sex  \
# 17           18         1       2  Williams     Mr. Charles Eugene  male
# 21           22         1       2   Beesley           Mr. Lawrence  male
# 23           24         1       1    Sloper   Mr. William Thompson  male
# 36           37         1       3     Mamee              Mr. Hanna  male
# 55           56         1       1   Woolner               Mr. Hugh  male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 17   NaN      0      0  244373  13.0000   NaN        S
# 21  34.0      0      0  248698  13.0000   D56        S
# 23  28.0      0      0  113788  35.5000    A6        S
# 36   NaN      0      0    2677   7.2292   NaN        C
# 55   NaN      0      0   19947  35.5000   C52        S

# %%
# Информация о выживших несовершеннолетних пассажирах мужского пола
df[(df['Sex']=='male') & (df['Survived']==1) & (df['Age']<18)].head()
# Out:
#      PassengerId  Survived  Pclass          Lname                  Name   Sex  \
# 78            79         1       2       Caldwell   Master. Alden Gates  male
# 125          126         1       3  Nicola-Yarred         Master. Elias  male
#
#        Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 78    0.83      0      2  248738  29.0000   NaN        S
# 125  12.00      1      0    2651  11.2417   NaN        C
